# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.interpolate import interp1d
import seaborn as sns
import os
from scipy.stats import pearsonr, spearmanr
from sklearn.metrics import mean_absolute_error, mean_squared_error
import pickle
import datetime 
import warnings
import sys
from datetime import timedelta
warnings.simplefilter(action='ignore', category=FutureWarning)

# from ClassFunctions_OtherRes import precip_time_series, rainfall_analysis
from PlottingFunctions import *

temp_res = 10

# For each file which has a 5 minute pickle file
for pickle_str in os.listdir(f'/nfs/a319/gy17m2a/MetricEvaluation/DanishRainDataPickles/')[66:67]:
    
    if 'svk' in pickle_str:
        directory = 'DanishRainData_SVK'
    else:
        directory = 'DanishRainData'    
    
    if 'svk' not in pickle_str:
    
        all_events = []

        file_name = pickle_str.split('.pkl')[0]
        if os.path.isfile(f"/nfs/a319/gy17m2a/MetricEvaluation/DanishRainData_Outputs/{temp_res}mins/All_events_new_{file_name}"):
            print("is file")
        else:
            print("is not file")

# %%
all_events_5mins =[]
all_events_30mins =[]

for file in os.listdir("../DanishRainData_Outputs/5mins/"):
    # Get 5 mintue data
    df_5mins = pd.read_csv(f"../DanishRainData_Outputs/5mins/{file}")
    # df_5mins['event_num']=range(0, len(df))
    df_5mins['event_num']=df_5mins.index
    # Get 30 minute data
    df_30mins = pd.read_csv(f"../DanishRainData_Outputs/{temp_res}mins/{file}")
    # Join, and get rid of events not present in 30 minute data
    df_5mins_filt = df_5mins[df_5mins['event_num'].isin(df_30mins['event_num'])]
    df_5mins_filt.reset_index(inplace=True, drop=True)
    print(file, len(df_5mins_filt), len(df_30mins))

    for i in range(len(df_5mins_filt)):
        start_30m = pd.to_datetime(df_30mins.iloc[i]['start_time'])
        start_5m = pd.to_datetime(df_5mins_filt.iloc[i]['start_time'])
        delta_start = abs(start_30m - start_5m)

        end_30m = pd.to_datetime(df_30mins.iloc[i]['end_time'])
        end_5m = pd.to_datetime(df_5mins_filt.iloc[i]['end_time'])
        delta_end = abs(end_30m - end_5m)
        # print(delta_end)

        if delta_start > timedelta(minutes=10):
            print(f"⚠️ Mismatch at index {i}:")
            print(f"  30-min start: {start_30m}")
            print(f"  5-min start : {start_5m}")
            print(f"  Difference  : {delta_start}")

        if delta_end > timedelta(minutes=10):
            print(f"⚠️ Mismatch at index {i}:")
            print(f"  30-min start: {start_30m}")
            print(f"  5-min start : {start_5m}")
            print(f"  Difference  : {delta_end}")


    all_events_5mins.append(df_5mins_filt)
    all_events_30mins.append(df_30mins)

all_events_df_5mins = pd.concat(all_events_5mins)   
all_events_df_30mins = pd.concat(all_events_30mins)   
print(len(all_events_df_5mins), len(all_events_df_30mins))

all_events_df_30mins.reset_index(inplace=True,drop=True)
# Out:
# All_events_5413_svk_precip_minute.csv 208 208
# All_events_610400_precip_minute.csv 929 929
# All_events_598120_precip_minute.csv 147 147
# All_events_5411_svk_precip_minute.csv 1372 1372
# All_events_588920_precip_minute.csv 911 911
# All_events_5555_svk_precip_minute.csv 1246 1246
# All_events_5653_svk_precip_minute.csv 543 543
# All_events_5052_svk_precip_minute.csv 2908 2908
# All_events_5990_svk_precip_minute.csv 2659 2659
# All_events_611900_precip_minute.csv 564 564
# All_events_5587_svk_precip_minute.csv 50 50
# All_events_540020_precip_minute.csv 1004 1004
# All_events_5418_svk_precip_minute.csv 218 218
# All_events_5390_svk_precip_minute.csv 3711 3711
# All_events_543520_precip_minute.csv 984 984
# All_events_5164_svk_precip_minute.csv 315 315
# All_events_5315_svk_precip_minute.csv 934 934
# All_events_5641_svk_precip_minute.csv 1473 1473
# All_events_5123_svk_precip_minute.csv 451 451
# All_events_532920_precip_minute.csv 1061 1061
# All_events_5699_svk_precip_minute.csv 1430 1430
# All_events_5240_svk_precip_minute.csv 1383 1383
# All_events_5057_svk_precip_minute.csv 2392 2392
# All_events_5465_svk_precip_minute.csv 2487 2487
# All_events_5572_svk_precip_minute.csv 702 702
# All_events_5790_svk_precip_minute.csv 2560 2560
# All_events_508520_precip_minute.csv 1007 1007
# All_events_5665_svk_precip_minute.csv 1564 1564
# All_events_5291_svk_precip_minute.csv 230 230
# All_events_5955_svk_precip_minute.csv 3201 3201
# All_events_508920_precip_minute.csv 1093 1093
# All_events_5930_svk_precip_minute.csv 1557 1557
# All_events_5804_svk_precip_minute.csv 1104 1104
# All_events_5509_svk_precip_minute.csv 1097 1097
# All_events_5597_svk_precip_minute.csv 57 57
# All_events_5870_svk_precip_minute.csv 1376 1376
# All_events_5856_svk_precip_minute.csv 32 32
# All_events_615600_precip_minute.csv 72 72
# All_events_607900_precip_minute.csv 474 474
# All_events_5445_svk_precip_minute.csv 1796 1796
# All_events_593520_precip_minute.csv 924 924
# All_events_5285_svk_precip_minute.csv 1935 1935
# All_events_5865_svk_precip_minute.csv 1333 1333
# All_events_5207_svk_precip_minute.csv 793 793
# All_events_522520_precip_minute.csv 1048 1048
# All_events_572220_precip_minute.csv 208 208
# All_events_5670_svk_precip_minute.csv 2543 2543
# All_events_5570_svk_precip_minute.csv 3808 3808
# All_events_554520_precip_minute.csv 950 950
# All_events_5176_svk_precip_minute.csv 643 643
# All_events_5178_svk_precip_minute.csv 633 633
# All_events_5595_svk_precip_minute.csv 47 47
# All_events_5915_svk_precip_minute.csv 1573 1573
# All_events_5262_svk_precip_minute.csv 421 421
# All_events_5161_svk_precip_minute.csv 310 310
# All_events_5755_svk_precip_minute.csv 3612 3612
# All_events_5840_svk_precip_minute.csv 1463 1463
# All_events_514020_precip_minute.csv 1065 1065
# All_events_5909_svk_precip_minute.csv 1526 1526
# All_events_5619_svk_precip_minute.csv 564 564
# All_events_5479_svk_precip_minute.csv 1533 1533
# All_events_5950_svk_precip_minute.csv 542 542
# All_events_5027_svk_precip_minute.csv 2761 2761
# All_events_532520_precip_minute.csv 88 88
# All_events_5715_svk_precip_minute.csv 1610 1610
# All_events_5705_svk_precip_minute.csv 2289 2289
# All_events_5592_svk_precip_minute.csv 47 47
# All_events_588020_precip_minute.csv 972 972
# All_events_5252_svk_precip_minute.csv 1344 1344
# All_events_5576_svk_precip_minute.csv 1062 1062
# All_events_614100_precip_minute.csv 42 42
# All_events_5717_svk_precip_minute.csv 1191 1191
# All_events_545520_precip_minute.csv 896 896
# All_events_605101_precip_minute.csv 433 433
# All_events_5625_svk_precip_minute.csv 3675 3675
# All_events_5335_svk_precip_minute.csv 503 503
# All_events_605800_precip_minute.csv 88 88
# All_events_5153_svk_precip_minute.csv 484 484
# All_events_5265_svk_precip_minute.csv 1428 1428
# All_events_540620_precip_minute.csv 727 727
# All_events_5058_svk_precip_minute.csv 2345 2345
# All_events_5750_svk_precip_minute.csv 3271 3271
# All_events_5602_svk_precip_minute.csv 833 833
# All_events_5585_svk_precip_minute.csv 1472 1472
# All_events_5504_svk_precip_minute.csv 22 22
# All_events_5588_svk_precip_minute.csv 49 49
# All_events_545020_precip_minute.csv 797 797
# All_events_5257_svk_precip_minute.csv 1344 1344
# All_events_520520_precip_minute.csv 1069 1069
# All_events_608800_precip_minute.csv 374 374
# All_events_5980_svk_precip_minute.csv 3361 3361
# All_events_603000_precip_minute.csv 714 714
# All_events_5239_svk_precip_minute.csv 1263 1263
# All_events_5874_svk_precip_minute.csv 937 937
# All_events_5565_svk_precip_minute.csv 1554 1554
# All_events_5409_svk_precip_minute.csv 1092 1092
# All_events_5920_svk_precip_minute.csv 1382 1382
# All_events_5054_svk_precip_minute.csv 2289 2289
# All_events_5690_svk_precip_minute.csv 1568 1568
# All_events_5172_svk_precip_minute.csv 564 564
# All_events_5940_svk_precip_minute.csv 870 870
# All_events_5429_svk_precip_minute.csv 1353 1353
# All_events_5115_svk_precip_minute.csv 2140 2140
# All_events_510520_precip_minute.csv 1127 1127
# All_events_5234_svk_precip_minute.csv 15 15
# All_events_5680_svk_precip_minute.csv 1623 1623
# All_events_5775_svk_precip_minute.csv 3548 3548
# All_events_598620_precip_minute.csv 1092 1092
# All_events_516020_precip_minute.csv 912 912
# All_events_5061_svk_precip_minute.csv 3282 3282
# All_events_551020_precip_minute.csv 1061 1061
# All_events_5273_svk_precip_minute.csv 1015 1015
# All_events_5540_svk_precip_minute.csv 3541 3541
# All_events_5427_svk_precip_minute.csv 2278 2278
# All_events_5425_svk_precip_minute.csv 1377 1377
# All_events_540820_precip_minute.csv 478 478
# All_events_5849_svk_precip_minute.csv 1437 1437
# All_events_5180_svk_precip_minute.csv 2775 2775
# All_events_5237_svk_precip_minute.csv 1918 1918
# All_events_546920_precip_minute.csv 900 900
# All_events_5247_svk_precip_minute.csv 1314 1314
# All_events_557520_precip_minute.csv 1050 1050
# All_events_527220_precip_minute.csv 1202 1202
# All_events_5810_svk_precip_minute.csv 3460 3460
# All_events_5422_svk_precip_minute.csv 3495 3495
# All_events_535020_precip_minute.csv 1080 1080
# All_events_5601_svk_precip_minute.csv 355 355
# All_events_5112_svk_precip_minute.csv 6 6
# All_events_619700_precip_minute.csv 758 758
# All_events_5419_svk_precip_minute.csv 3653 3653
# All_events_610200_precip_minute.csv 8 8
# All_events_5598_svk_precip_minute.csv 62 62
# All_events_5578_svk_precip_minute.csv 1056 1056
# All_events_5195_svk_precip_minute.csv 1398 1398
# All_events_5710_svk_precip_minute.csv 3577 3577
# All_events_613600_precip_minute.csv 647 647
# All_events_5414_svk_precip_minute.csv 200 200
# All_events_5163_svk_precip_minute.csv 298 298
# All_events_5645_svk_precip_minute.csv 1484 1484
# All_events_5800_svk_precip_minute.csv 2419 2419
# All_events_507020_precip_minute.csv 1028 1028
# All_events_5025_svk_precip_minute.csv 2632 2632
# All_events_607200_precip_minute.csv 70 70
# All_events_534520_precip_minute.csv 1217 1217
# All_events_5174_svk_precip_minute.csv 632 632
# All_events_5623_svk_precip_minute.csv 657 657
# All_events_5694_svk_precip_minute.csv 3709 3709
# All_events_5124_svk_precip_minute.csv 418 418
# All_events_5697_svk_precip_minute.csv 1155 1155
# All_events_5130_svk_precip_minute.csv 1394 1394
# All_events_615400_precip_minute.csv 48 48
# All_events_529020_precip_minute.csv 1115 1115
# All_events_5183_svk_precip_minute.csv 655 655
# All_events_518520_precip_minute.csv 1041 1041
# All_events_5404_svk_precip_minute.csv 200 200
# All_events_5622_svk_precip_minute.csv 663 663
# All_events_5633_svk_precip_minute.csv 3662 3662
# All_events_5525_svk_precip_minute.csv 474 474
# All_events_5503_svk_precip_minute.csv 24 24
# All_events_610900_precip_minute.csv 96 96
# All_events_5245_svk_precip_minute.csv 1344 1344
# All_events_605200_precip_minute.csv 804 804
# All_events_5122_svk_precip_minute.csv 1791 1791
# All_events_5573_svk_precip_minute.csv 323 323
# All_events_5698_svk_precip_minute.csv 621 621
# All_events_5542_svk_precip_minute.csv 29 29
# All_events_5495_svk_precip_minute.csv 812 812
# All_events_549920_precip_minute.csv 1042 1042
# All_events_500520_precip_minute.csv 1075 1075
# All_events_5012_svk_precip_minute.csv 291 291
# All_events_5975_svk_precip_minute.csv 309 309
# All_events_614700_precip_minute.csv 63 63
# All_events_5660_svk_precip_minute.csv 1582 1582
# All_events_612600_precip_minute.csv 77 77
# All_events_5385_svk_precip_minute.csv 621 621
# All_events_606500_precip_minute.csv 901 901
# All_events_5045_svk_precip_minute.csv 2078 2078
# All_events_5725_svk_precip_minute.csv 2402 2402
# All_events_5643_svk_precip_minute.csv 656 656
# All_events_573520_precip_minute.csv 828 828
# All_events_5211_svk_precip_minute.csv 3351 3351
# All_events_5581_svk_precip_minute.csv 300 300
# All_events_538120_precip_minute.csv 975 975
# All_events_5859_svk_precip_minute.csv 1427 1427
# All_events_538420_precip_minute.csv 15 15
# All_events_5630_svk_precip_minute.csv 325 325
# All_events_617000_precip_minute.csv 649 649
# All_events_5461_svk_precip_minute.csv 1958 1958
# All_events_5192_svk_precip_minute.csv 3879 3879
# All_events_616900_precip_minute.csv 59 59
# All_events_5733_svk_precip_minute.csv 221 221
# All_events_5805_svk_precip_minute.csv 2344 2344
# All_events_5125_svk_precip_minute.csv 446 446
# All_events_532020_precip_minute.csv 1016 1016
# All_events_5594_svk_precip_minute.csv 56 56
# All_events_597020_precip_minute.csv 968 968
# All_events_5727_svk_precip_minute.csv 1116 1116
# All_events_5201_svk_precip_minute.csv 1042 1042
# All_events_526920_precip_minute.csv 976 976
# All_events_5175_svk_precip_minute.csv 2906 2906
# All_events_5620_svk_precip_minute.csv 1660 1660
# All_events_5580_svk_precip_minute.csv 2763 2763
# All_events_506520_precip_minute.csv 996 996
# All_events_5260_svk_precip_minute.csv 1394 1394
# All_events_5145_svk_precip_minute.csv 1751 1751
# All_events_5759_svk_precip_minute.csv 3408 3408
# All_events_5397_svk_precip_minute.csv 1277 1277
# All_events_618800_precip_minute.csv 47 47
# All_events_536520_precip_minute.csv 1167 1167
# All_events_503120_precip_minute.csv 1023 1023
# All_events_5586_svk_precip_minute.csv 52 52
# All_events_5283_svk_precip_minute.csv 1035 1035
# All_events_5574_svk_precip_minute.csv 1017 1017
# All_events_5230_svk_precip_minute.csv 1407 1407
# All_events_520220_precip_minute.csv 1119 1119
# All_events_5675_svk_precip_minute.csv 1621 1621
# All_events_5251_svk_precip_minute.csv 3987 3987
# All_events_5232_svk_precip_minute.csv 1370 1370
# All_events_615900_precip_minute.csv 694 694
# All_events_5610_svk_precip_minute.csv 2100 2100
# All_events_5607_svk_precip_minute.csv 620 620
# All_events_5591_svk_precip_minute.csv 57 57
# All_events_5049_svk_precip_minute.csv 2169 2169
# All_events_5155_svk_precip_minute.csv 1398 1398
# All_events_5403_svk_precip_minute.csv 1038 1038
# All_events_516920_precip_minute.csv 1034 1034
# All_events_5631_svk_precip_minute.csv 85 85
# All_events_5281_svk_precip_minute.csv 1030 1030
# All_events_537520_precip_minute.csv 916 916
# All_events_5593_svk_precip_minute.csv 803 803
# All_events_5599_svk_precip_minute.csv 56 56
# All_events_5655_svk_precip_minute.csv 1570 1570
# All_events_5628_svk_precip_minute.csv 944 944
# All_events_5502_svk_precip_minute.csv 25 25
# All_events_5703_svk_precip_minute.csv 1140 1140
# All_events_501520_precip_minute.csv 915 915
# All_events_5815_svk_precip_minute.csv 2293 2293
# All_events_5515_svk_precip_minute.csv 1861 1861
# All_events_5190_svk_precip_minute.csv 1705 1705
# All_events_618000_precip_minute.csv 919 919
# All_events_5490_svk_precip_minute.csv 2405 2405
# All_events_5765_svk_precip_minute.csv 3447 3447
# All_events_5713_svk_precip_minute.csv 574 574
# All_events_5824_svk_precip_minute.csv 691 691
# All_events_5855_svk_precip_minute.csv 1445 1445
# All_events_599420_precip_minute.csv 969 969
# All_events_5501_svk_precip_minute.csv 25 25
# All_events_596020_precip_minute.csv 541 541
# All_events_5200_svk_precip_minute.csv 1017 1017
# All_events_603100_precip_minute.csv 824 824
# All_events_544020_precip_minute.csv 960 960
# All_events_5407_svk_precip_minute.csv 1054 1054
# All_events_5650_svk_precip_minute.csv 1232 1232
# All_events_5282_svk_precip_minute.csv 991 991
# All_events_5254_svk_precip_minute.csv 1032 1032
# All_events_5415_svk_precip_minute.csv 3548 3548
# All_events_613800_precip_minute.csv 419 419
# All_events_5550_svk_precip_minute.csv 785 785
# All_events_5359_svk_precip_minute.csv 2786 2786
# All_events_5377_svk_precip_minute.csv 1084 1084
# All_events_5685_svk_precip_minute.csv 1551 1551
# All_events_5857_svk_precip_minute.csv 22 22
# All_events_550520_precip_minute.csv 798 798
# All_events_539520_precip_minute.csv 1000 1000
# All_events_5740_svk_precip_minute.csv 3584 3584
# All_events_5825_svk_precip_minute.csv 1357 1357
# All_events_5181_svk_precip_minute.csv 649 649
# All_events_617400_precip_minute.csv 66 66
# All_events_500920_precip_minute.csv 937 937
# All_events_5637_svk_precip_minute.csv 333 333
# All_events_5577_svk_precip_minute.csv 1028 1028
# All_events_619300_precip_minute.csv 629 629
# All_events_5459_svk_precip_minute.csv 1044 1044
# All_events_5179_svk_precip_minute.csv 641 641
# All_events_504020_precip_minute.csv 232 232
# All_events_509520_precip_minute.csv 1091 1091
# All_events_5925_svk_precip_minute.csv 3452 3452
# All_events_5879_svk_precip_minute.csv 1542 1542
# All_events_508120_precip_minute.csv 1123 1123
# All_events_606000_precip_minute.csv 992 992
# All_events_5032_svk_precip_minute.csv 428 428
# All_events_5117_svk_precip_minute.csv 2138 2138
# All_events_572020_precip_minute.csv 182 182
# All_events_515020_precip_minute.csv 1075 1075
# All_events_5177_svk_precip_minute.csv 3560 3560
# All_events_510920_precip_minute.csv 973 973
# All_events_5745_svk_precip_minute.csv 2380 2380
# All_events_5781_svk_precip_minute.csv 3351 3351
# All_events_5370_svk_precip_minute.csv 3777 3777
# All_events_5785_svk_precip_minute.csv 704 704
# All_events_5596_svk_precip_minute.csv 818 818
# All_events_5047_svk_precip_minute.csv 3643 3643
# All_events_522020_precip_minute.csv 1128 1128
# All_events_5830_svk_precip_minute.csv 1331 1331
# All_events_5248_svk_precip_minute.csv 1352 1352
# All_events_5363_svk_precip_minute.csv 1068 1068
# All_events_5310_svk_precip_minute.csv 679 679
# All_events_5279_svk_precip_minute.csv 3946 3946
# All_events_5275_svk_precip_minute.csv 879 879
# All_events_5905_svk_precip_minute.csv 1554 1554
# All_events_503520_precip_minute.csv 994 994
# All_events_5732_svk_precip_minute.csv 226 226
# All_events_5629_svk_precip_minute.csv 88 88
# All_events_5579_svk_precip_minute.csv 342 342
# All_events_5615_svk_precip_minute.csv 327 327
# All_events_5107_svk_precip_minute.csv 1200 1200
# All_events_5235_svk_precip_minute.csv 3607 3607
# All_events_5795_svk_precip_minute.csv 3486 3486
# All_events_530020_precip_minute.csv 977 977
# All_events_5605_svk_precip_minute.csv 672 672
# All_events_5618_svk_precip_minute.csv 621 621
# All_events_5600_svk_precip_minute.csv 3553 3553
# All_events_5255_svk_precip_minute.csv 1355 1355
# All_events_5647_svk_precip_minute.csv 646 646
# All_events_5243_svk_precip_minute.csv 2558 2558
# All_events_5162_svk_precip_minute.csv 299 299
# All_events_608200_precip_minute.csv 101 101
# All_events_5649_svk_precip_minute.csv 1415 1415
# All_events_5721_svk_precip_minute.csv 805 805
# All_events_513520_precip_minute.csv 1020 1020
# All_events_5412_svk_precip_minute.csv 364 364
# All_events_618400_precip_minute.csv 107 107
# All_events_5835_svk_precip_minute.csv 1387 1387
# All_events_529520_precip_minute.csv 21 21
# All_events_5845_svk_precip_minute.csv 3448 3448
# All_events_540520_precip_minute.csv 207 207
# All_events_5121_svk_precip_minute.csv 1780 1780
# All_events_5771_svk_precip_minute.csv 1665 1665
# All_events_5056_svk_precip_minute.csv 2309 2309
# All_events_5901_svk_precip_minute.csv 1552 1552
# All_events_5731_svk_precip_minute.csv 195 195
# All_events_5485_svk_precip_minute.csv 1716 1716
# All_events_5521_svk_precip_minute.csv 1832 1832
# All_events_5560_svk_precip_minute.csv 1598 1598
# All_events_5417_svk_precip_minute.csv 2865 2865
# All_events_519920_precip_minute.csv 922 922
# All_events_5730_svk_precip_minute.csv 2747 2747
# All_events_604100_precip_minute.csv 163 163
# All_events_5763_svk_precip_minute.csv 513 513
# All_events_601900_precip_minute.csv 569 569
# All_events_607000_precip_minute.csv 1125 1125
# All_events_530520_precip_minute.csv 1153 1153
# All_events_5590_svk_precip_minute.csv 2610 2610
# All_events_529620_precip_minute.csv 926 926
# All_events_5340_svk_precip_minute.csv 3923 3923
# All_events_5642_svk_precip_minute.csv 695 695
# 437564 437564

# %% [markdown]
# ### ---------

# %% [markdown]
# ### Get a version with just the 'raw' versions of the metrics

# %%
raw_cols = []
for col in all_events_df_5mins.columns:
    if not col.endswith('_DMC_10') and not col.endswith('dblnorm'):
        raw_cols.append(col)
        
unneeded_cols = ['gauge_num',  'start_time', 'end_time','total_precip', 'duration','peak_mean_ratio_scaled',
                'frac_q1', 'frac_q2', 'frac_q3', 'frac_q4',]       
raw_cols = [x for x in raw_cols if x not in unneeded_cols]      
        
all_events_df_5mins_raw = all_events_df_5mins[raw_cols]
all_events_df_30mins_raw = all_events_df_30mins[raw_cols]

# %% [markdown]
# ### Check for columns containing nan (none for 5 mins)

# %%
columns_with_nan = all_events_df_30mins_raw.columns[all_events_df_30mins_raw.isnull().any()].tolist()
print("Columns with at least one NaN value:")
print(columns_with_nan)

this=all_events_df_30mins_raw[all_events_df_30mins_raw.isnull().any(axis=1)]
this['event_num']
# Out:
# Columns with at least one NaN value:
# ['asymm_d', 'event_loading_ghanghas', 'lorentz_asymetry', 'mean_intensity_high_intensity_zone']
# 232455     57
# 235769    302
# 400595    444
# Name: event_num, dtype: int64

# %% [markdown]
# ### Delete column in both dataframes with the nan value

# %%
all_events_df_30mins_raw = all_events_df_30mins_raw[all_events_df_30mins_raw['event_num']!=302]
all_events_df_5mins_raw = all_events_df_5mins_raw[all_events_df_5mins_raw['event_num']!=302]
del all_events_df_30mins_raw['event_num']
del all_events_df_5mins_raw['event_num']

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
from scipy.stats import ks_2samp
results = []
for metric in raw_cols:
    data_5min = all_events_df_5mins[metric]
    data_30min = all_events_df_30mins[metric]
    ks_statistic, p_value = ks_2samp(data_5min, data_30min)
    results.append({"metric":metric, "KS Statistic" : ks_statistic, "p-value" : p_value})

results_df = pd.DataFrame(results)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

results = []

for metric in raw_cols:
    y_true = all_events_df_5mins_raw[metric]
    y_pred = all_events_df_30mins_raw[metric]
    
    mae = mean_absolute_error(y_true, y_pred)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    
    ks_statistic, p_value = ks_2samp(y_true, y_pred)
    
    results.append({'Metric': metric, 'mean_5mins': y_true.mean() , 'mean_30mins': y_pred.mean(),  'MAE': mae, 'MAPE': mape, 
                    'RMSE': rmse,"KS Statistic" : ks_statistic, "p-value" : p_value})

results_df = pd.DataFrame(results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_15173/1741644336.py in <module>
#       7     y_pred = all_events_df_30mins_raw[metric]
#       8
# ----> 9     mae = mean_absolute_error(y_true, y_pred)
#      10     mape = mean_absolute_percentage_error(y_true, y_pred)
#      11     rmse = np.sqrt(mean_squared_error(y_true, y_pred))
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/sklearn/metrics/_regression.py in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     190     """
#     191     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 192         y_true, y_pred, multioutput
#     193     )
#     194     check_consistent_length(y_true, y_pred, sample_weight)
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      93     """
#      94     check_consistent_length(y_true, y_pred)
# ---> 95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#      97
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     114             raise ValueError(
#     115                 msg_err.format(
# --> 116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117                 )
#     118             )
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Define the metrics to plot
metrics = raw_cols # Adjust this list as needed

# Determine the number of rows and columns for the subplot grid
n_cols = 5  # Number of columns in the grid
n_rows = int(np.ceil(len(metrics) / n_cols))  # Calculate the required number of rows

# Create the subplot grid
fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 4, n_rows * 3), constrained_layout=True)
axes = axes.flatten()  # Flatten the 2D array of axes for easy iteration

# Loop through each metric and create the corresponding subplot
for idx, metric in enumerate(metrics):
    ax = axes[idx]
    
    ax.scatter(all_events_df_5mins_raw[metric], all_events_df_30mins_raw[metric])
    
    # Set the title and labels
    ax.set_title(f'Distribution of {metric}')
    ax.set_xlabel(metric)
    ax.set_ylabel('Density')

# Hide any unused subplots
for idx in range(len(metrics), len(axes)):
    fig.delaxes(axes[idx])

# Display the plot
plt.show()

# %%
all_events_df_30mins_raw[all_events_df_30mins_raw["mean_intensity"]>200]
# Out:
# Empty DataFrame
# Columns: [I30, time_to_peak, peak_position_ratio, third_ppr, std, max_intensity, mean_intensity, min_intensity, cv, skewness, kurtosis, relative_amp, peak_mean_ratio, PCI, TCI, asymm_d, event_loading_ghanghas, NRMSE_P, skewp, gini, lorentz_asymetry, intermittency, event_dry_ratio, ni, time_skewness, time_kurtosis, centre_gravity, centre_gravity_interpolated, m1, m2, m3, m4, m5, m1_wi, m2_wi, m3_wi, m4_wi, m5_wi, frac_q1_wi_, frac_q2_wi_, frac_q3_wi_, frac_q4_wi_, frac_time_in_high_intensity_zone, frac_time_in_low_intensity_zone, frac_rain_in_high_intensity_zone, mean_intensity_high_intensity_zone, 3rd_w_peak, 4th_w_peak, 5th_w_peak, 3rd_com, 3rd_ARR, T25, T50, T75, D50, BSC, BSC_Index]
# Index: []
#
# [0 rows x 57 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Define the metrics to plot
metrics = raw_cols # Adjust this list as needed

# Determine the number of rows and columns for the subplot grid
n_cols = 5  # Number of columns in the grid
n_rows = int(np.ceil(len(metrics) / n_cols))  # Calculate the required number of rows

# Create the subplot grid
fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 4, n_rows * 3), constrained_layout=True)
axes = axes.flatten()  # Flatten the 2D array of axes for easy iteration

# Loop through each metric and create the corresponding subplot
for idx, metric in enumerate(metrics):
    ax = axes[idx]
    
    # Plot the histogram for the 5-minute data
    sns.histplot(
        data=all_events_df_5mins_raw[metric],
        stat='density',
        bins=100,
        alpha=0.5,
        color='blue',
        label='5-minute',
        ax=ax
    )
    
    # Plot the histogram for the 30-minute data
    sns.histplot(
        data=all_events_df_30mins_raw[metric],
        stat='density',
        bins=100,
        alpha=0.5,
        color='orange',
        label='30-minute',
        ax=ax
    )
    
    # Set the title and labels
    ax.set_title(f'Distribution of {metric}')
    ax.set_xlabel(metric)
    ax.set_ylabel('Density')
    ax.legend()

# Hide any unused subplots
for idx in range(len(metrics), len(axes)):
    fig.delaxes(axes[idx])

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Define the metrics to plot
metrics = raw_cols # Adjust this list as needed

# Determine the number of rows and columns for the subplot grid
n_cols = 5  # Number of columns in the grid
n_rows = int(np.ceil(len(metrics) / n_cols))  # Calculate the required number of rows

# Create the subplot grid
fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 4, n_rows * 3), constrained_layout=True)
axes = axes.flatten()  # Flatten the 2D array of axes for easy iteration

# Loop through each metric and create the corresponding subplot
for idx, metric in enumerate(metrics):
    ax = axes[idx]
    
    # Plot the histogram for the 5-minute data
    sns.histplot(
        data=all_events_df_5mins_raw[metric],
        stat='density',
        bins=100,
        alpha=0.5,
        color='blue',
        label='5-minute',
        ax=ax
    )
    
    # Plot the histogram for the 30-minute data
    sns.histplot(
        data=all_events_df_30mins_raw[metric],
        stat='density',
        bins=100,
        alpha=0.5,
        color='orange',
        label='30-minute',
        ax=ax
    )
    
    # Set the title and labels
    ax.set_title(f'Distribution of {metric}')
    ax.set_xlabel(metric)
    ax.set_ylabel('Density')
    ax.legend()

# Hide any unused subplots
for idx in range(len(metrics), len(axes)):
    fig.delaxes(axes[idx])

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'event_num'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5677/3618567831.py in <module>
#      20     # Plot the histogram for the 5-minute data
#      21     sns.histplot(
# ---> 22         data=all_events_df_5mins_raw[metric],
#      23         stat='density',
#      24         bins=100,
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'event_num'
