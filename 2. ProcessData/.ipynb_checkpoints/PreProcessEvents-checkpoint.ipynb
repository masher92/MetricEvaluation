# %% [markdown]
# ## Join all files together

# %%
# Get the list of files (assuming all resolutions have the same filenames)
files = np.sort([f for f in os.listdir(os.path.join(input_datadir, "5mins_new_new")) if f.endswith(".csv")])

len(files)
# Out:
# 289

# %%
import pandas as pd
import numpy as np
import os
from datetime import timedelta

input_datadir = '/scratch/hydro4/users/kv25483/MetricEvaluation/Data/DanishRainData_Outputs'
resolutions = [5, 10, 30, 60]  # in minutes

all_events_list = []  # to store merged per-file data
total_events = 0

# Get the list of files (assuming all resolutions have the same filenames)
files = np.sort([f for f in os.listdir(os.path.join(input_datadir, "5mins_new_new")) if f.endswith(".csv")])

for num, file in enumerate(files[:290]):  # first 7 for testing
    # --- Step 1: read all resolutions ---
    dfs = {}
    for res in resolutions:
        df = pd.read_csv(os.path.join(input_datadir, f"{res}mins_new_new", file))
        df['event_num'] = df.index  # ensure we have event_num
        df['gauge_num'] = df['gauge_num'].apply(
            lambda x: int(x.split('_')[0]) if isinstance(x, str) and x.split('_')[0].isdigit() else x)
        
        # Add suffix to metrics to indicate resolution
        metric_cols = [c for c in df.columns if c not in ['event_num', 'gauge_num']]
        df.rename(columns={c: f"{c}_{res}m" for c in metric_cols}, inplace=True)
        dfs[res] = df

    # --- Step 2: find common events across all resolutions ---
    common_event_nums = set.intersection(*(set(df['event_num']) for df in dfs.values()))
    
    if not common_event_nums:
        print("No common event numbers")
        continue

    # Filter dfs to only include common events
    for res in resolutions:
        dfs[res] = dfs[res][dfs[res]['event_num'].isin(common_event_nums)].reset_index(drop=True)

    # --- Step 3: merge all resolutions side-by-side ---
    merged = dfs[5]
    for res in [10, 30, 60]:
        merged = merged.merge(dfs[res], on=['event_num', 'gauge_num'], how='inner')

    total_events += len(merged)
    print(f"{num} : {file}: {len(common_event_nums)} events retained across all resolutions, new total: {total_events}")

    all_events_list.append(merged)

# --- Step 4: concatenate all files ---
all_events_df = pd.concat(all_events_list).reset_index(drop=True)
print("Final shape:", all_events_df.shape)
# Out:
# 0 : All_events_500520_precip_minute.csv: 1083 events retained across all resolutions, new total: 1083
# 1 : All_events_500920_precip_minute.csv: 944 events retained across all resolutions, new total: 2027
# 2 : All_events_5012_svk_precip_minute.csv: 293 events retained across all resolutions, new total: 2320
# 3 : All_events_501520_precip_minute.csv: 920 events retained across all resolutions, new total: 3240
# 4 : All_events_5025_svk_precip_minute.csv: 2667 events retained across all resolutions, new total: 5907
# 5 : All_events_5027_svk_precip_minute.csv: 2804 events retained across all resolutions, new total: 8711
# 6 : All_events_503120_precip_minute.csv: 1042 events retained across all resolutions, new total: 9753
# 7 : All_events_5032_svk_precip_minute.csv: 436 events retained across all resolutions, new total: 10189
# 8 : All_events_503520_precip_minute.csv: 1004 events retained across all resolutions, new total: 11193
# 9 : All_events_504020_precip_minute.csv: 237 events retained across all resolutions, new total: 11430
# 10 : All_events_504220_precip_minute.csv: 880 events retained across all resolutions, new total: 12310
# 11 : All_events_5045_svk_precip_minute.csv: 2120 events retained across all resolutions, new total: 14430
# 12 : All_events_5047_svk_precip_minute.csv: 3719 events retained across all resolutions, new total: 18149
# 13 : All_events_5049_svk_precip_minute.csv: 2210 events retained across all resolutions, new total: 20359
# 14 : All_events_5052_svk_precip_minute.csv: 2968 events retained across all resolutions, new total: 23327
# 15 : All_events_5054_svk_precip_minute.csv: 2333 events retained across all resolutions, new total: 25660
# 16 : All_events_5056_svk_precip_minute.csv: 2353 events retained across all resolutions, new total: 28013
# 17 : All_events_5057_svk_precip_minute.csv: 2435 events retained across all resolutions, new total: 30448
# 18 : All_events_5058_svk_precip_minute.csv: 2391 events retained across all resolutions, new total: 32839
# 19 : All_events_5061_svk_precip_minute.csv: 3342 events retained across all resolutions, new total: 36181
# 20 : All_events_506520_precip_minute.csv: 1015 events retained across all resolutions, new total: 37196
# 21 : All_events_507020_precip_minute.csv: 1044 events retained across all resolutions, new total: 38240
# 22 : All_events_507520_precip_minute.csv: 1085 events retained across all resolutions, new total: 39325
# 23 : All_events_508120_precip_minute.csv: 1128 events retained across all resolutions, new total: 40453
# 24 : All_events_508520_precip_minute.csv: 1015 events retained across all resolutions, new total: 41468
# 25 : All_events_508920_precip_minute.csv: 1105 events retained across all resolutions, new total: 42573
# 26 : All_events_509520_precip_minute.csv: 1100 events retained across all resolutions, new total: 43673
# 27 : All_events_510520_precip_minute.csv: 1142 events retained across all resolutions, new total: 44815
# 28 : All_events_5107_svk_precip_minute.csv: 1219 events retained across all resolutions, new total: 46034
# 29 : All_events_510920_precip_minute.csv: 982 events retained across all resolutions, new total: 47016
# 30 : All_events_5112_svk_precip_minute.csv: 6 events retained across all resolutions, new total: 47022
# 31 : All_events_5115_svk_precip_minute.csv: 2172 events retained across all resolutions, new total: 49194
# 32 : All_events_5117_svk_precip_minute.csv: 2169 events retained across all resolutions, new total: 51363
# 33 : All_events_5121_svk_precip_minute.csv: 1801 events retained across all resolutions, new total: 53164
# 34 : All_events_5122_svk_precip_minute.csv: 1825 events retained across all resolutions, new total: 54989
# 35 : All_events_5123_svk_precip_minute.csv: 459 events retained across all resolutions, new total: 55448
# 36 : All_events_5124_svk_precip_minute.csv: 425 events retained across all resolutions, new total: 55873
# 37 : All_events_5125_svk_precip_minute.csv: 451 events retained across all resolutions, new total: 56324
# 38 : All_events_5130_svk_precip_minute.csv: 1410 events retained across all resolutions, new total: 57734
# 39 : All_events_513520_precip_minute.csv: 1032 events retained across all resolutions, new total: 58766
# 40 : All_events_514020_precip_minute.csv: 1071 events retained across all resolutions, new total: 59837
# 41 : All_events_5145_svk_precip_minute.csv: 1795 events retained across all resolutions, new total: 61632
# 42 : All_events_515020_precip_minute.csv: 1091 events retained across all resolutions, new total: 62723
# 43 : All_events_5153_svk_precip_minute.csv: 497 events retained across all resolutions, new total: 63220
# 44 : All_events_5155_svk_precip_minute.csv: 1423 events retained across all resolutions, new total: 64643
# 45 : All_events_516020_precip_minute.csv: 931 events retained across all resolutions, new total: 65574
# 46 : All_events_5161_svk_precip_minute.csv: 315 events retained across all resolutions, new total: 65889
# 47 : All_events_5162_svk_precip_minute.csv: 304 events retained across all resolutions, new total: 66193
# 48 : All_events_5163_svk_precip_minute.csv: 305 events retained across all resolutions, new total: 66498
# 49 : All_events_5164_svk_precip_minute.csv: 318 events retained across all resolutions, new total: 66816
# 50 : All_events_516520_precip_minute.csv: 826 events retained across all resolutions, new total: 67642
# 51 : All_events_516920_precip_minute.csv: 1045 events retained across all resolutions, new total: 68687
# 52 : All_events_5172_svk_precip_minute.csv: 575 events retained across all resolutions, new total: 69262
# 53 : All_events_5174_svk_precip_minute.csv: 643 events retained across all resolutions, new total: 69905
# 54 : All_events_5175_svk_precip_minute.csv: 2964 events retained across all resolutions, new total: 72869
# 55 : All_events_5176_svk_precip_minute.csv: 656 events retained across all resolutions, new total: 73525
# 56 : All_events_5177_svk_precip_minute.csv: 3642 events retained across all resolutions, new total: 77167
# 57 : All_events_5178_svk_precip_minute.csv: 646 events retained across all resolutions, new total: 77813
# 58 : All_events_5179_svk_precip_minute.csv: 652 events retained across all resolutions, new total: 78465
# 59 : All_events_5180_svk_precip_minute.csv: 2844 events retained across all resolutions, new total: 81309
# 60 : All_events_5181_svk_precip_minute.csv: 660 events retained across all resolutions, new total: 81969
# 61 : All_events_5183_svk_precip_minute.csv: 664 events retained across all resolutions, new total: 82633
# 62 : All_events_518520_precip_minute.csv: 1057 events retained across all resolutions, new total: 83690
# 63 : All_events_5190_svk_precip_minute.csv: 1731 events retained across all resolutions, new total: 85421
# 64 : All_events_5192_svk_precip_minute.csv: 3948 events retained across all resolutions, new total: 89369
# 65 : All_events_5195_svk_precip_minute.csv: 1421 events retained across all resolutions, new total: 90790
# 66 : All_events_519920_precip_minute.csv: 933 events retained across all resolutions, new total: 91723
# 67 : All_events_5200_svk_precip_minute.csv: 1031 events retained across all resolutions, new total: 92754
# 68 : All_events_5201_svk_precip_minute.csv: 1060 events retained across all resolutions, new total: 93814
# 69 : All_events_520220_precip_minute.csv: 1131 events retained across all resolutions, new total: 94945
# 70 : All_events_520520_precip_minute.csv: 1081 events retained across all resolutions, new total: 96026
# 71 : All_events_5207_svk_precip_minute.csv: 808 events retained across all resolutions, new total: 96834
# 72 : All_events_5211_svk_precip_minute.csv: 3408 events retained across all resolutions, new total: 100242
# 73 : All_events_5215_svk_precip_minute.csv: 347 events retained across all resolutions, new total: 100589
# 74 : All_events_522020_precip_minute.csv: 1148 events retained across all resolutions, new total: 101737
# 75 : All_events_522520_precip_minute.csv: 1062 events retained across all resolutions, new total: 102799
# 76 : All_events_5230_svk_precip_minute.csv: 1430 events retained across all resolutions, new total: 104229
# 77 : All_events_5232_svk_precip_minute.csv: 1387 events retained across all resolutions, new total: 105616
# 78 : All_events_5234_svk_precip_minute.csv: 16 events retained across all resolutions, new total: 105632
# 79 : All_events_5235_svk_precip_minute.csv: 3672 events retained across all resolutions, new total: 109304
# 80 : All_events_5237_svk_precip_minute.csv: 1958 events retained across all resolutions, new total: 111262
# 81 : All_events_5239_svk_precip_minute.csv: 1283 events retained across all resolutions, new total: 112545
# 82 : All_events_5240_svk_precip_minute.csv: 1408 events retained across all resolutions, new total: 113953
# 83 : All_events_5243_svk_precip_minute.csv: 2608 events retained across all resolutions, new total: 116561
# 84 : All_events_5245_svk_precip_minute.csv: 1370 events retained across all resolutions, new total: 117931
# 85 : All_events_5247_svk_precip_minute.csv: 1343 events retained across all resolutions, new total: 119274
# 86 : All_events_5248_svk_precip_minute.csv: 1374 events retained across all resolutions, new total: 120648
# 87 : All_events_5251_svk_precip_minute.csv: 4052 events retained across all resolutions, new total: 124700
# 88 : All_events_5252_svk_precip_minute.csv: 1367 events retained across all resolutions, new total: 126067
# 89 : All_events_5254_svk_precip_minute.csv: 1046 events retained across all resolutions, new total: 127113
# 90 : All_events_5255_svk_precip_minute.csv: 1377 events retained across all resolutions, new total: 128490
# 91 : All_events_5257_svk_precip_minute.csv: 1367 events retained across all resolutions, new total: 129857
# 92 : All_events_5260_svk_precip_minute.csv: 1410 events retained across all resolutions, new total: 131267
# 93 : All_events_5262_svk_precip_minute.csv: 430 events retained across all resolutions, new total: 131697
# 94 : All_events_5265_svk_precip_minute.csv: 1451 events retained across all resolutions, new total: 133148
# 95 : All_events_526920_precip_minute.csv: 986 events retained across all resolutions, new total: 134134
# 96 : All_events_527220_precip_minute.csv: 1211 events retained across all resolutions, new total: 135345
# 97 : All_events_5273_svk_precip_minute.csv: 1030 events retained across all resolutions, new total: 136375
# 98 : All_events_5275_svk_precip_minute.csv: 895 events retained across all resolutions, new total: 137270
# 99 : All_events_527620_precip_minute.csv: 948 events retained across all resolutions, new total: 138218
# 100 : All_events_527720_precip_minute.csv: 1194 events retained across all resolutions, new total: 139412
# 101 : All_events_5279_svk_precip_minute.csv: 4003 events retained across all resolutions, new total: 143415
# 102 : All_events_5281_svk_precip_minute.csv: 1041 events retained across all resolutions, new total: 144456
# 103 : All_events_5282_svk_precip_minute.csv: 1008 events retained across all resolutions, new total: 145464
# 104 : All_events_5283_svk_precip_minute.csv: 1053 events retained across all resolutions, new total: 146517
# 105 : All_events_5285_svk_precip_minute.csv: 1958 events retained across all resolutions, new total: 148475
# 106 : All_events_529020_precip_minute.csv: 1129 events retained across all resolutions, new total: 149604
# 107 : All_events_5291_svk_precip_minute.csv: 234 events retained across all resolutions, new total: 149838
# 108 : All_events_529520_precip_minute.csv: 21 events retained across all resolutions, new total: 149859
# 109 : All_events_529620_precip_minute.csv: 934 events retained across all resolutions, new total: 150793
# 110 : All_events_530020_precip_minute.csv: 984 events retained across all resolutions, new total: 151777
# 111 : All_events_530520_precip_minute.csv: 1170 events retained across all resolutions, new total: 152947
# 112 : All_events_5310_svk_precip_minute.csv: 698 events retained across all resolutions, new total: 153645
# 113 : All_events_5315_svk_precip_minute.csv: 950 events retained across all resolutions, new total: 154595
# 114 : All_events_532020_precip_minute.csv: 1031 events retained across all resolutions, new total: 155626
# 115 : All_events_532520_precip_minute.csv: 88 events retained across all resolutions, new total: 155714
# 116 : All_events_532920_precip_minute.csv: 1072 events retained across all resolutions, new total: 156786
# 117 : All_events_5335_svk_precip_minute.csv: 508 events retained across all resolutions, new total: 157294
# 118 : All_events_5340_svk_precip_minute.csv: 3990 events retained across all resolutions, new total: 161284
# 119 : All_events_534320_precip_minute.csv: 905 events retained across all resolutions, new total: 162189
# 120 : All_events_534520_precip_minute.csv: 1237 events retained across all resolutions, new total: 163426
# 121 : All_events_535020_precip_minute.csv: 1089 events retained across all resolutions, new total: 164515
# 122 : All_events_535520_precip_minute.csv: 1029 events retained across all resolutions, new total: 165544
# 123 : All_events_5359_svk_precip_minute.csv: 2831 events retained across all resolutions, new total: 168375
# 124 : All_events_5363_svk_precip_minute.csv: 1084 events retained across all resolutions, new total: 169459
# 125 : All_events_536520_precip_minute.csv: 1191 events retained across all resolutions, new total: 170650
# 126 : All_events_5370_svk_precip_minute.csv: 3856 events retained across all resolutions, new total: 174506
# 127 : All_events_537520_precip_minute.csv: 931 events retained across all resolutions, new total: 175437
# 128 : All_events_5377_svk_precip_minute.csv: 1099 events retained across all resolutions, new total: 176536
# 129 : All_events_538120_precip_minute.csv: 987 events retained across all resolutions, new total: 177523
# 130 : All_events_538420_precip_minute.csv: 15 events retained across all resolutions, new total: 177538
# 131 : All_events_5385_svk_precip_minute.csv: 632 events retained across all resolutions, new total: 178170
# 132 : All_events_5390_svk_precip_minute.csv: 3785 events retained across all resolutions, new total: 181955
# 133 : All_events_539520_precip_minute.csv: 1017 events retained across all resolutions, new total: 182972
# 134 : All_events_5397_svk_precip_minute.csv: 1289 events retained across all resolutions, new total: 184261
# 135 : All_events_540020_precip_minute.csv: 1010 events retained across all resolutions, new total: 185271
# 136 : All_events_5403_svk_precip_minute.csv: 1065 events retained across all resolutions, new total: 186336
# 137 : All_events_5404_svk_precip_minute.csv: 204 events retained across all resolutions, new total: 186540
# 138 : All_events_540520_precip_minute.csv: 210 events retained across all resolutions, new total: 186750
# 139 : All_events_540620_precip_minute.csv: 735 events retained across all resolutions, new total: 187485
# 140 : All_events_5407_svk_precip_minute.csv: 1082 events retained across all resolutions, new total: 188567
# 141 : All_events_540820_precip_minute.csv: 488 events retained across all resolutions, new total: 189055
# 142 : All_events_5409_svk_precip_minute.csv: 1111 events retained across all resolutions, new total: 190166
# 143 : All_events_5411_svk_precip_minute.csv: 1404 events retained across all resolutions, new total: 191570
# 144 : All_events_5412_svk_precip_minute.csv: 370 events retained across all resolutions, new total: 191940
# 145 : All_events_5413_svk_precip_minute.csv: 212 events retained across all resolutions, new total: 192152
# 146 : All_events_5414_svk_precip_minute.csv: 204 events retained across all resolutions, new total: 192356
# 147 : All_events_5415_svk_precip_minute.csv: 3628 events retained across all resolutions, new total: 195984
# 148 : All_events_5417_svk_precip_minute.csv: 2931 events retained across all resolutions, new total: 198915
# 149 : All_events_5418_svk_precip_minute.csv: 226 events retained across all resolutions, new total: 199141
# 150 : All_events_5419_svk_precip_minute.csv: 3721 events retained across all resolutions, new total: 202862
# 151 : All_events_5422_svk_precip_minute.csv: 3571 events retained across all resolutions, new total: 206433
# 152 : All_events_5425_svk_precip_minute.csv: 1399 events retained across all resolutions, new total: 207832
# 153 : All_events_5427_svk_precip_minute.csv: 2331 events retained across all resolutions, new total: 210163
# 154 : All_events_5429_svk_precip_minute.csv: 1377 events retained across all resolutions, new total: 211540
# 155 : All_events_543520_precip_minute.csv: 997 events retained across all resolutions, new total: 212537
# 156 : All_events_544020_precip_minute.csv: 977 events retained across all resolutions, new total: 213514
# 157 : All_events_5445_svk_precip_minute.csv: 1850 events retained across all resolutions, new total: 215364
# 158 : All_events_545020_precip_minute.csv: 812 events retained across all resolutions, new total: 216176
# 159 : All_events_545520_precip_minute.csv: 913 events retained across all resolutions, new total: 217089
# 160 : All_events_5459_svk_precip_minute.csv: 1064 events retained across all resolutions, new total: 218153
# 161 : All_events_5461_svk_precip_minute.csv: 2012 events retained across all resolutions, new total: 220165
# 162 : All_events_5465_svk_precip_minute.csv: 2552 events retained across all resolutions, new total: 222717
# 163 : All_events_546920_precip_minute.csv: 916 events retained across all resolutions, new total: 223633
# 164 : All_events_5475_svk_precip_minute.csv: 749 events retained across all resolutions, new total: 224382
# 165 : All_events_5479_svk_precip_minute.csv: 1577 events retained across all resolutions, new total: 225959
# 166 : All_events_5485_svk_precip_minute.csv: 1770 events retained across all resolutions, new total: 227729
# 167 : All_events_5490_svk_precip_minute.csv: 2469 events retained across all resolutions, new total: 230198
# 168 : All_events_5495_svk_precip_minute.csv: 838 events retained across all resolutions, new total: 231036
# 169 : All_events_549920_precip_minute.csv: 1061 events retained across all resolutions, new total: 232097
# 170 : All_events_5501_svk_precip_minute.csv: 25 events retained across all resolutions, new total: 232122
# 171 : All_events_5502_svk_precip_minute.csv: 25 events retained across all resolutions, new total: 232147
# 172 : All_events_5503_svk_precip_minute.csv: 25 events retained across all resolutions, new total: 232172
# 173 : All_events_5504_svk_precip_minute.csv: 22 events retained across all resolutions, new total: 232194
# 174 : All_events_550520_precip_minute.csv: 813 events retained across all resolutions, new total: 233007
# 175 : All_events_5509_svk_precip_minute.csv: 1124 events retained across all resolutions, new total: 234131
# 176 : All_events_551020_precip_minute.csv: 1085 events retained across all resolutions, new total: 235216
# 177 : All_events_5515_svk_precip_minute.csv: 1909 events retained across all resolutions, new total: 237125
# 178 : All_events_5521_svk_precip_minute.csv: 1883 events retained across all resolutions, new total: 239008
# 179 : All_events_5525_svk_precip_minute.csv: 483 events retained across all resolutions, new total: 239491
# 180 : All_events_552920_precip_minute.csv: 945 events retained across all resolutions, new total: 240436
# 181 : All_events_553720_precip_minute.csv: 881 events retained across all resolutions, new total: 241317
# 182 : All_events_5540_svk_precip_minute.csv: 3623 events retained across all resolutions, new total: 244940
# 183 : All_events_5542_svk_precip_minute.csv: 29 events retained across all resolutions, new total: 244969
# 184 : All_events_554520_precip_minute.csv: 971 events retained across all resolutions, new total: 245940
# 185 : All_events_5550_svk_precip_minute.csv: 803 events retained across all resolutions, new total: 246743
# 186 : All_events_5555_svk_precip_minute.csv: 1288 events retained across all resolutions, new total: 248031
# 187 : All_events_5560_svk_precip_minute.csv: 1620 events retained across all resolutions, new total: 249651
# 188 : All_events_5565_svk_precip_minute.csv: 1588 events retained across all resolutions, new total: 251239
# 189 : All_events_5570_svk_precip_minute.csv: 3896 events retained across all resolutions, new total: 255135
# 190 : All_events_5572_svk_precip_minute.csv: 721 events retained across all resolutions, new total: 255856
# 191 : All_events_5573_svk_precip_minute.csv: 333 events retained across all resolutions, new total: 256189
# 192 : All_events_5574_svk_precip_minute.csv: 1036 events retained across all resolutions, new total: 257225
# 193 : All_events_557520_precip_minute.csv: 1064 events retained across all resolutions, new total: 258289
# 194 : All_events_5576_svk_precip_minute.csv: 1089 events retained across all resolutions, new total: 259378
# 195 : All_events_5577_svk_precip_minute.csv: 1065 events retained across all resolutions, new total: 260443
# 196 : All_events_5578_svk_precip_minute.csv: 1089 events retained across all resolutions, new total: 261532
# 197 : All_events_5579_svk_precip_minute.csv: 350 events retained across all resolutions, new total: 261882
# 198 : All_events_5580_svk_precip_minute.csv: 2832 events retained across all resolutions, new total: 264714
# 199 : All_events_5581_svk_precip_minute.csv: 304 events retained across all resolutions, new total: 265018
# 200 : All_events_5585_svk_precip_minute.csv: 1516 events retained across all resolutions, new total: 266534
# 201 : All_events_5586_svk_precip_minute.csv: 54 events retained across all resolutions, new total: 266588
# 202 : All_events_5587_svk_precip_minute.csv: 53 events retained across all resolutions, new total: 266641
# 203 : All_events_5588_svk_precip_minute.csv: 51 events retained across all resolutions, new total: 266692
# 204 : All_events_5590_svk_precip_minute.csv: 2667 events retained across all resolutions, new total: 269359
# 205 : All_events_5591_svk_precip_minute.csv: 57 events retained across all resolutions, new total: 269416
# 206 : All_events_5592_svk_precip_minute.csv: 47 events retained across all resolutions, new total: 269463
# 207 : All_events_5593_svk_precip_minute.csv: 819 events retained across all resolutions, new total: 270282
# 208 : All_events_5594_svk_precip_minute.csv: 59 events retained across all resolutions, new total: 270341
# 209 : All_events_5595_svk_precip_minute.csv: 49 events retained across all resolutions, new total: 270390
# 210 : All_events_5596_svk_precip_minute.csv: 837 events retained across all resolutions, new total: 271227
# 211 : All_events_5597_svk_precip_minute.csv: 57 events retained across all resolutions, new total: 271284
# 212 : All_events_5598_svk_precip_minute.csv: 64 events retained across all resolutions, new total: 271348
# 213 : All_events_5599_svk_precip_minute.csv: 56 events retained across all resolutions, new total: 271404
# 214 : All_events_5600_svk_precip_minute.csv: 3642 events retained across all resolutions, new total: 275046
# 215 : All_events_5601_svk_precip_minute.csv: 365 events retained across all resolutions, new total: 275411
# 216 : All_events_5602_svk_precip_minute.csv: 851 events retained across all resolutions, new total: 276262
# 217 : All_events_5605_svk_precip_minute.csv: 693 events retained across all resolutions, new total: 276955
# 218 : All_events_5607_svk_precip_minute.csv: 640 events retained across all resolutions, new total: 277595
# 219 : All_events_5610_svk_precip_minute.csv: 2147 events retained across all resolutions, new total: 279742
# 220 : All_events_5615_svk_precip_minute.csv: 336 events retained across all resolutions, new total: 280078
# 221 : All_events_5618_svk_precip_minute.csv: 641 events retained across all resolutions, new total: 280719
# 222 : All_events_5619_svk_precip_minute.csv: 585 events retained across all resolutions, new total: 281304
# 223 : All_events_5620_svk_precip_minute.csv: 1707 events retained across all resolutions, new total: 283011
# 224 : All_events_5622_svk_precip_minute.csv: 681 events retained across all resolutions, new total: 283692
# 225 : All_events_5623_svk_precip_minute.csv: 679 events retained across all resolutions, new total: 284371
# 226 : All_events_5625_svk_precip_minute.csv: 3762 events retained across all resolutions, new total: 288133
# 227 : All_events_5628_svk_precip_minute.csv: 964 events retained across all resolutions, new total: 289097
# 228 : All_events_5629_svk_precip_minute.csv: 94 events retained across all resolutions, new total: 289191
# 229 : All_events_5630_svk_precip_minute.csv: 334 events retained across all resolutions, new total: 289525
# 230 : All_events_5631_svk_precip_minute.csv: 88 events retained across all resolutions, new total: 289613
# 231 : All_events_5633_svk_precip_minute.csv: 3746 events retained across all resolutions, new total: 293359
# 232 : All_events_5637_svk_precip_minute.csv: 338 events retained across all resolutions, new total: 293697
# 233 : All_events_5641_svk_precip_minute.csv: 1505 events retained across all resolutions, new total: 295202
# 234 : All_events_5642_svk_precip_minute.csv: 709 events retained across all resolutions, new total: 295911
# 235 : All_events_5643_svk_precip_minute.csv: 676 events retained across all resolutions, new total: 296587
# 236 : All_events_5645_svk_precip_minute.csv: 1511 events retained across all resolutions, new total: 298098
# 237 : All_events_5647_svk_precip_minute.csv: 660 events retained across all resolutions, new total: 298758
# 238 : All_events_5649_svk_precip_minute.csv: 1455 events retained across all resolutions, new total: 300213
# 239 : All_events_5650_svk_precip_minute.csv: 1255 events retained across all resolutions, new total: 301468
# 240 : All_events_5653_svk_precip_minute.csv: 560 events retained across all resolutions, new total: 302028
# 241 : All_events_5655_svk_precip_minute.csv: 1597 events retained across all resolutions, new total: 303625
# 242 : All_events_5660_svk_precip_minute.csv: 1606 events retained across all resolutions, new total: 305231
# 243 : All_events_5665_svk_precip_minute.csv: 1603 events retained across all resolutions, new total: 306834
# 244 : All_events_5670_svk_precip_minute.csv: 2583 events retained across all resolutions, new total: 309417
# 245 : All_events_5675_svk_precip_minute.csv: 1641 events retained across all resolutions, new total: 311058
# 246 : All_events_5680_svk_precip_minute.csv: 1653 events retained across all resolutions, new total: 312711
# 247 : All_events_5685_svk_precip_minute.csv: 1579 events retained across all resolutions, new total: 314290
# 248 : All_events_5690_svk_precip_minute.csv: 1598 events retained across all resolutions, new total: 315888
# 249 : All_events_5694_svk_precip_minute.csv: 3783 events retained across all resolutions, new total: 319671
# 250 : All_events_5697_svk_precip_minute.csv: 1179 events retained across all resolutions, new total: 320850
# 251 : All_events_5698_svk_precip_minute.csv: 636 events retained across all resolutions, new total: 321486
# 252 : All_events_5699_svk_precip_minute.csv: 1466 events retained across all resolutions, new total: 322952
# 253 : All_events_5703_svk_precip_minute.csv: 1170 events retained across all resolutions, new total: 324122
# 254 : All_events_5705_svk_precip_minute.csv: 2347 events retained across all resolutions, new total: 326469
# 255 : All_events_5710_svk_precip_minute.csv: 3660 events retained across all resolutions, new total: 330129
# 256 : All_events_5713_svk_precip_minute.csv: 590 events retained across all resolutions, new total: 330719
# 257 : All_events_5715_svk_precip_minute.csv: 1647 events retained across all resolutions, new total: 332366
# 258 : All_events_5717_svk_precip_minute.csv: 1215 events retained across all resolutions, new total: 333581
# 259 : All_events_572020_precip_minute.csv: 184 events retained across all resolutions, new total: 333765
# 260 : All_events_5721_svk_precip_minute.csv: 826 events retained across all resolutions, new total: 334591
# 261 : All_events_572220_precip_minute.csv: 210 events retained across all resolutions, new total: 334801
# 262 : All_events_5725_svk_precip_minute.csv: 2457 events retained across all resolutions, new total: 337258
# 263 : All_events_5727_svk_precip_minute.csv: 1136 events retained across all resolutions, new total: 338394
# 264 : All_events_5730_svk_precip_minute.csv: 2814 events retained across all resolutions, new total: 341208
# 265 : All_events_5731_svk_precip_minute.csv: 199 events retained across all resolutions, new total: 341407
# 266 : All_events_5732_svk_precip_minute.csv: 230 events retained across all resolutions, new total: 341637
# 267 : All_events_5733_svk_precip_minute.csv: 227 events retained across all resolutions, new total: 341864
# 268 : All_events_573520_precip_minute.csv: 843 events retained across all resolutions, new total: 342707
# 269 : All_events_5740_svk_precip_minute.csv: 3670 events retained across all resolutions, new total: 346377
# 270 : All_events_5745_svk_precip_minute.csv: 2429 events retained across all resolutions, new total: 348806
# 271 : All_events_5750_svk_precip_minute.csv: 3347 events retained across all resolutions, new total: 352153
# 272 : All_events_5755_svk_precip_minute.csv: 3686 events retained across all resolutions, new total: 355839
# 273 : All_events_5759_svk_precip_minute.csv: 3481 events retained across all resolutions, new total: 359320
# 274 : All_events_5763_svk_precip_minute.csv: 526 events retained across all resolutions, new total: 359846
# 275 : All_events_5765_svk_precip_minute.csv: 3512 events retained across all resolutions, new total: 363358
# 276 : All_events_5771_svk_precip_minute.csv: 1701 events retained across all resolutions, new total: 365059
# 277 : All_events_5775_svk_precip_minute.csv: 3635 events retained across all resolutions, new total: 368694
# 278 : All_events_5781_svk_precip_minute.csv: 3461 events retained across all resolutions, new total: 372155
# 279 : All_events_5785_svk_precip_minute.csv: 722 events retained across all resolutions, new total: 372877
# 280 : All_events_5790_svk_precip_minute.csv: 2620 events retained across all resolutions, new total: 375497
# 281 : All_events_5795_svk_precip_minute.csv: 3561 events retained across all resolutions, new total: 379058
# 282 : All_events_5800_svk_precip_minute.csv: 2465 events retained across all resolutions, new total: 381523
# 283 : All_events_5804_svk_precip_minute.csv: 1122 events retained across all resolutions, new total: 382645
# 284 : All_events_5805_svk_precip_minute.csv: 2403 events retained across all resolutions, new total: 385048
# 285 : All_events_5810_svk_precip_minute.csv: 3545 events retained across all resolutions, new total: 388593
# 286 : All_events_5815_svk_precip_minute.csv: 2333 events retained across all resolutions, new total: 390926
# 287 : All_events_5824_svk_precip_minute.csv: 708 events retained across all resolutions, new total: 391634
# 288 : All_events_5825_svk_precip_minute.csv: 1392 events retained across all resolutions, new total: 393026
# 289 : All_events_5830_svk_precip_minute.csv: 1372 events retained across all resolutions, new total: 394398
# Final shape: (394398, 682)

# %% [markdown]
# ### Get rid of small events

# %%
flag_cols = ['mapping_flag_5m', 'mapping_flag_10m', 'mapping_flag_30m', 'mapping_flag_60m']

# for col in cols:
#     print(f"\n{col}")
#     print(all_events_df[col].value_counts(dropna=False))
    
print(len(all_events_df))
all_events_df = all_events_df[
    all_events_df[flag_cols].isna().all(axis=1)].copy()    
print(len(all_events_df))
# Out:
# 394398
# 394179

# %%
all_events_df = all_events_df[all_events_df['total_precip_5m']>4].copy()

# %% [markdown]
# ### Get rid of big events

# %%
bad_indices = all_events_df.sort_values(by="total_precip_5m", ascending=False)[:15].index

# Drop rows at these indices from all dataframes
all_events_df = all_events_df.drop(index=bad_indices)

# %% [markdown]
# ### Set I30 to 0 for 60m (from NAN) - and add _raw to the string

# %%
all_events_df["I30_60m"] = 0

# %%
all_events_df.columns = [
    col.replace('I30', 'I30_raw') if 'I30' in col else col
    for col in all_events_df.columns]

# %% [markdown]
# ### Get rid of unwanted columns

# %%
# Specify the suffixes to remove
cols_to_remove = ['T50', 'norm_time_std']

# Keep only columns that do NOT contain any of the above
all_events_df = all_events_df[
    [col for col in all_events_df.columns 
     if not any(suffix in col for suffix in cols_to_remove)]].copy()

# %% [markdown]
# ### Create normalised version of temporal std

# %%
# Specify the suffixes to remove
cols_to_remove = ['T50']

# Keep only columns that do NOT contain any of the above
all_events_df = all_events_df[
    [col for col in all_events_df.columns 
     if not any(suffix in col for suffix in cols_to_remove)]].copy()

# %%
# resolutions = ['5m', '10m', '30m', '60m']
# types = ['raw', 'dblnorm', 'dmc']

# for t in types:
#     for res in resolutions:
#         time_col = f'time_std_{t}_{res}'
#         dur_col = f'duration_{t}_{res}'
#         new_col = f'norm_time_std_{t}_{res}'
        
#         # Create normalised column
#         all_events_df[new_col] = all_events_df[time_col] / all_events_df[dur_col]
        
#         # Drop original time_std column
#         all_events_df.drop(columns=time_col, inplace=True)

# %% [markdown]
# ### Get version with just raw data

# %%
# Specify the suffixes to remove
versions_to_remove = ['_dblnorm', '_dmc']

# Keep only columns that do NOT contain any of the above
events_raw = all_events_df[
    [col for col in all_events_df.columns 
     if not any(suffix in col for suffix in versions_to_remove)]].copy()
events_raw.columns = [col.replace('_raw', '') for col in events_raw.columns]

# %%
# # Select all columns except the flag ones
# df_check = events_raw.drop(columns=['mapping_flag_5m'])

# # Find NaN locations
# nan_locs = np.where(df_check.isna())

# list(zip(df_check.index[nan_locs[0]], df_check.columns[nan_locs[1]]))

# %% [markdown]
# ### Get version with just 5m data

# %%
# Specify the suffixes to remove
res_to_remove = ['_10m', '_30m', '_60m']

# Keep only columns that do NOT contain any of the above
events_5m = all_events_df[
    [col for col in all_events_df.columns 
     if not any(suffix in col for suffix in res_to_remove)]].copy()

events_5m.columns = [col.replace('_5m', '') for col in events_5m.columns]

# %% [markdown]
# ### Get version with just 5m, just raw data

# %%
# Keep only columns that do NOT contain any of the above
events_raw_5m = events_raw[
    [col for col in events_raw.columns 
     if not any(suffix in col for suffix in res_to_remove)]].copy()

events_raw_5m.columns = [col.replace('_5m', '') for col in events_raw_5m.columns]

events_raw_5m.drop(['gauge_num', 'event_num', 'start_time', 'end_time', 'mapping_flag'], axis=1, inplace=True)

# %% [markdown]
# ### Save to file

# %%
output_datadir = '/scratch/hydro4/users/kv25483/MetricEvaluation/Data/'
all_events_df.to_csv(output_datadir + "IntermediateFiles/AllRes.csv",index=False)
events_5m.to_csv(output_datadir + "IntermediateFiles/Just5m.csv",index=False)
events_raw.to_csv(output_datadir + "IntermediateFiles/Justraw.csv",index=False)
events_raw_5m.to_csv(output_datadir + "IntermediateFiles/Justraw_5m.csv",index=False)
